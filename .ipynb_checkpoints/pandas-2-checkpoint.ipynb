# %% [markdown]
# [dataset](https://github.com/Shubham007-web/Dummy_datasets/blob/main/bike_dataset.csv)

# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/df.csv')
df1
# Out:
#        Name  Age  Salary  Experience  Gender
# 0   Himadri   21      15         1.0  Female
# 1    Hritik   20      36         1.2    Male
# 2  Sriyanka   22      14         2.0  Female
# 3   Utkarsh   23      12         0.5    Male
# 4     Rahul   21      16        11.0    Male
# 5  Niharika   22      11         1.0  Female
# 6  Himanhsu   24      13         1.4    Male
# 7    Saloni   21       9         1.2  Female
# 8    Ayshui   20      10         0.5  Female
# 9    Shivam   24      12         1.0    Male

# %%
df2 = pd.read_excel('/content/df.xlsx')
df2
# Out:
#        Name   Age  Experience
# 0     Rahul   NaN         1.0
# 1    Shivam  24.0         2.0
# 2     Priti  26.0         NaN
# 3     Uttam   NaN         1.0
# 4    Deepak  26.0         1.2
# 5  Ravindra  22.0         2.0
# 6   Shubham  24.0         2.1
# 7    Anjali  21.0         NaN

# %% [markdown]
# **Attributes of DataFrame**
# - index, columns, shape, size, ndim, T, values, axes, dtype

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
df1.columns
# Out:
# Index(['Name', 'Age', 'Salary', 'Experience', 'Gender'], dtype='object')

# %%
df1.axes
# Out:
# [RangeIndex(start=0, stop=10, step=1),
#  Index(['Name', 'Age', 'Salary', 'Experience', 'Gender'], dtype='object')]

# %%
df1.values
# Out:
# array([['Himadri', 21, 15, 1.0, 'Female'],
#        ['Hritik', 20, 36, 1.2, 'Male'],
#        ['Sriyanka', 22, 14, 2.0, 'Female'],
#        ['Utkarsh', 23, 12, 0.5, 'Male'],
#        ['Rahul', 21, 16, 11.0, 'Male'],
#        ['Niharika', 22, 11, 1.0, 'Female'],
#        ['Himanhsu', 24, 13, 1.4, 'Male'],
#        ['Saloni', 21, 9, 1.2, 'Female'],
#        ['Ayshui', 20, 10, 0.5, 'Female'],
#        ['Shivam', 24, 12, 1.0, 'Male']], dtype=object)

# %%
df1.shape
# Out:
# (10, 5)

# %%
df1.size
# Out:
# 50

# %%
# df1.iloc[:,2].dtype

# %%
df1['Name'].dtype
# Out:
# dtype('O')

# %%
df1.ndim
# Out:
# 2

# %%
df1.T
# Out:
#                   0       1         2        3      4         5         6  \
# Name        Himadri  Hritik  Sriyanka  Utkarsh  Rahul  Niharika  Himanhsu
# Age              21      20        22       23     21        22        24
# Salary           15      36        14       12     16        11        13
# Experience      1.0     1.2       2.0      0.5   11.0       1.0       1.4
# Gender       Female    Male    Female     Male   Male    Female      Male
#
#                  7       8       9
# Name        Saloni  Ayshui  Shivam
# Age             21      20      24
# Salary           9      10      12
# Experience     1.2     0.5     1.0
# Gender      Female  Female    Male

# %% [markdown]
# ## **Methods of DataFrame**
# **Indexing & slicing**
# - loc[]
# - iloc[]

# %%
df1
# Out:
#        Name  Age  Salary  Experience  Gender
# 0   Himadri   21      15         1.0  Female
# 1    Hritik   20      36         1.2    Male
# 2  Sriyanka   22      14         2.0  Female
# 3   Utkarsh   23      12         0.5    Male
# 4     Rahul   21      16        11.0    Male
# 5  Niharika   22      11         1.0  Female
# 6  Himanhsu   24      13         1.4    Male
# 7    Saloni   21       9         1.2  Female
# 8    Ayshui   20      10         0.5  Female
# 9    Shivam   24      12         1.0    Male

# %%
df1.loc[5,'Age']
# Out:
# 22

# %%
df1.iloc[5,-1]
# Out:
# 'Female'

# %%
df1.loc[[8,2,6], ['Name','Age',"Gender"]]
# Out:
#        Name  Age  Gender
# 8    Ayshui   20  Female
# 2  Sriyanka   22  Female
# 6  Himanhsu   24    Male

# %%
df1.loc[4:8, "Name":'Experience']
# Out:
#        Name  Age  Salary  Experience
# 4     Rahul   21      16        11.0
# 5  Niharika   22      11         1.0
# 6  Himanhsu   24      13         1.4
# 7    Saloni   21       9         1.2
# 8    Ayshui   20      10         0.5

# %%
# iloc[]
df1.iloc[[7,2,4],[0,1,4]]
# Out:
#        Name  Age  Gender
# 7    Saloni   21  Female
# 2  Sriyanka   22  Female
# 4     Rahul   21    Male

# %%
df1.iloc[4:8,0:4]
# Out:
#        Name  Age  Salary  Experience
# 4     Rahul   21      16        11.0
# 5  Niharika   22      11         1.0
# 6  Himanhsu   24      13         1.4
# 7    Saloni   21       9         1.2

# %% [markdown]
# **Filtering**

# %%
df1
# Out:
#        Name  Age  Salary  Experience  Gender
# 0   Himadri   21      15         1.0  Female
# 1    Hritik   20      36         1.2    Male
# 2  Sriyanka   22      14         2.0  Female
# 3   Utkarsh   23      12         0.5    Male
# 4     Rahul   21      16        11.0    Male
# 5  Niharika   22      11         1.0  Female
# 6  Himanhsu   24      13         1.4    Male
# 7    Saloni   21       9         1.2  Female
# 8    Ayshui   20      10         0.5  Female
# 9    Shivam   24      12         1.0    Male

# %%
df1[df1['Gender'] == 'Female']
# Out:
#        Name  Age  Salary  Experience  Gender
# 0   Himadri   21      15         1.0  Female
# 2  Sriyanka   22      14         2.0  Female
# 5  Niharika   22      11         1.0  Female
# 7    Saloni   21       9         1.2  Female
# 8    Ayshui   20      10         0.5  Female

# %%
df1[df1['Experience'] >= 1.2]
# Out:
#        Name  Age  Salary  Experience  Gender
# 1    Hritik   20      36         1.2    Male
# 2  Sriyanka   22      14         2.0  Female
# 4     Rahul   21      16        11.0    Male
# 6  Himanhsu   24      13         1.4    Male
# 7    Saloni   21       9         1.2  Female

# %%
df1[(df1['Salary'] > 10) & (df1['Experience'] >= 1.2) ]
# Out:
#        Name  Age  Salary  Experience  Gender
# 1    Hritik   20      36         1.2    Male
# 2  Sriyanka   22      14         2.0  Female
# 4     Rahul   21      16        11.0    Male
# 6  Himanhsu   24      13         1.4    Male

# %% [markdown]
# **sorting dataframe**

# %%
df1.sort_values('Age',axis = 0,ascending=False,ignore_index = True)
# Out:
#        Name  Age  Salary  Experience  Gender
# 0  Himanhsu   24      13         1.4    Male
# 1    Shivam   24      12         1.0    Male
# 2   Utkarsh   23      12         0.5    Male
# 3  Sriyanka   22      14         2.0  Female
# 4  Niharika   22      11         1.0  Female
# 5   Himadri   21      15         1.0  Female
# 6     Rahul   21      16        11.0    Male
# 7    Saloni   21       9         1.2  Female
# 8    Hritik   20      36         1.2    Male
# 9    Ayshui   20      10         0.5  Female

# %% [markdown]
# #### **Some Useful methods**
# head(), tail(), info(), drop_duplicate(), sample()

# %%
df1.head()
# Out:
#        Name  Age  Salary  Experience  Gender
# 0   Himadri   21      15         1.0  Female
# 1    Hritik   20      36         1.2    Male
# 2  Sriyanka   22      14         2.0  Female
# 3   Utkarsh   23      12         0.5    Male
# 4     Rahul   21      16        11.0    Male

# %%
df1.tail(3)
# Out:
#      Name  Age  Salary  Experience  Gender
# 7  Saloni   21       9         1.2  Female
# 8  Ayshui   20      10         0.5  Female
# 9  Shivam   24      12         1.0    Male

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        10 non-null     object
#  1   Age         10 non-null     int64
#  2   Salary      10 non-null     int64
#  3   Experience  10 non-null     float64
#  4   Gender      10 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 528.0+ bytes

# %%
df1.drop_duplicates()
# Out:
#        Name  Age  Salary  Experience  Gender
# 0   Himadri   21      15         1.0  Female
# 1    Hritik   20      36         1.2    Male
# 2  Sriyanka   22      14         2.0  Female
# 3   Utkarsh   23      12         0.5    Male
# 4     Rahul   21      16        11.0    Male
# 5  Niharika   22      11         1.0  Female
# 6  Himanhsu   24      13         1.4    Male
# 7    Saloni   21       9         1.2  Female
# 8    Ayshui   20      10         0.5  Female
# 9    Shivam   24      12         1.0    Male

# %%
df1.sample(n = 3)
# Out:
#        Name  Age  Salary  Experience  Gender
# 6  Himanhsu   24      13         1.4    Male
# 5  Niharika   22      11         1.0  Female
# 9    Shivam   24      12         1.0    Male

# %%
df1.sample(frac= 0.3)
# Out:
#        Name  Age  Salary  Experience  Gender
# 2  Sriyanka   22      14         2.0  Female
# 5  Niharika   22      11         1.0  Female
# 6  Himanhsu   24      13         1.4    Male

# %% [markdown]
# - drop(), value_counts(), unique(), nunique(), replace(),to_datetime, date_range()

# %%
# nunique()
df1['Gender'].nunique()
# Out:
# 2

# %%
# unique()
df1['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# value_counts()
df1['Gender'].value_counts()
# Out:
# Female    5
# Male      5
# Name: Gender, dtype: int64

# %%
# drop
df1.drop('Age', axis = 1)
# df1.drop('Age', axis = 1, inplace = True)
# Out:
#        Name  Salary  Experience  Gender
# 0   Himadri      15         1.0  Female
# 1    Hritik      36         1.2    Male
# 2  Sriyanka      14         2.0  Female
# 3   Utkarsh      12         0.5    Male
# 4     Rahul      16        11.0    Male
# 5  Niharika      11         1.0  Female
# 6  Himanhsu      13         1.4    Male
# 7    Saloni       9         1.2  Female
# 8    Ayshui      10         0.5  Female
# 9    Shivam      12         1.0    Male

# %%
# replace
df1.replace({'Male' : 'M', "Female": "F"}, inplace =True)

# %%
df1.head()
# Out:
#        Name  Age  Salary  Experience Gender
# 0   Himadri   21      15         1.0      F
# 1    Hritik   20      36         1.2      M
# 2  Sriyanka   22      14         2.0      F
# 3   Utkarsh   23      12         0.5      M
# 4     Rahul   21      16        11.0      M

# %% [markdown]
# - to_datetime()
# - date_range()  [time offset](https://pandas.pydata.org/docs/user_guide/timeseries.html#timeseries-offset-aliases)

# %%
s = ['27- dec - 2022', '1-1-2023']
type(s)
# Out:
# list

# %%
d  = pd.to_datetime(s)
d
# Out:
# DatetimeIndex(['2022-12-27', '2023-01-01'], dtype='datetime64[ns]', freq=None)

# %%
d.day_name(), d.day, d.day_of_year, d.dayofweek
# Out:
# (Index(['Tuesday', 'Sunday'], dtype='object'),
#  Int64Index([27, 1], dtype='int64'),
#  Int64Index([361, 1], dtype='int64'),
#  Int64Index([1, 6], dtype='int64'))

# %%
pd.to_datetime('15 aug 1947').day_name()
# Out:
# 'Friday'

# %%
pd.date_range(start = '27 dec 22', end = '26 Jan 24', freq= '3M' )
# Out:
# DatetimeIndex(['2022-12-31', '2023-03-31', '2023-06-30', '2023-09-30',
#                '2023-12-31'],
#               dtype='datetime64[ns]', freq='3M')

# %%
pd.date_range(start = '1 jan 23',  end = '1 feb 23', freq= 'B')
# Out:
# DatetimeIndex(['2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05',
#                '2023-01-06', '2023-01-09', '2023-01-10', '2023-01-11',
#                '2023-01-12', '2023-01-13', '2023-01-16', '2023-01-17',
#                '2023-01-18', '2023-01-19', '2023-01-20', '2023-01-23',
#                '2023-01-24', '2023-01-25', '2023-01-26', '2023-01-27',
#                '2023-01-30', '2023-01-31', '2023-02-01'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range(start = '1 jan 23',  periods= 20, freq= 'W')
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-08', '2023-01-15', '2023-01-22',
#                '2023-01-29', '2023-02-05', '2023-02-12', '2023-02-19',
#                '2023-02-26', '2023-03-05', '2023-03-12', '2023-03-19',
#                '2023-03-26', '2023-04-02', '2023-04-09', '2023-04-16',
#                '2023-04-23', '2023-04-30', '2023-05-07', '2023-05-14'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range(start = '1 jan 23',  periods= 20, freq= 'MS')
# Out:
# DatetimeIndex(['2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01',
#                '2023-09-01', '2023-10-01', '2023-11-01', '2023-12-01',
#                '2024-01-01', '2024-02-01', '2024-03-01', '2024-04-01',
#                '2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
d2 = df1.copy()
d2.head()
# Out:
#        Name  Age  Salary  Experience Gender
# 0   Himadri   21      15         1.0      F
# 1    Hritik   20      36         1.2      M
# 2  Sriyanka   22      14         2.0      F
# 3   Utkarsh   23      12         0.5      M
# 4     Rahul   21      16        11.0      M

# %%
dat = pd.date_range(start = '1 jan 2019', periods = 10, freq= '3MS')
dat
# Out:
# DatetimeIndex(['2019-01-01', '2019-04-01', '2019-07-01', '2019-10-01',
#                '2020-01-01', '2020-04-01', '2020-07-01', '2020-10-01',
#                '2021-01-01', '2021-04-01'],
#               dtype='datetime64[ns]', freq='3MS')

# %%
d2.set_index(dat, inplace= True)

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10 entries, 2019-01-01 to 2021-04-01
# Freq: 3MS
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        10 non-null     object
#  1   Age         10 non-null     int64
#  2   Salary      10 non-null     int64
#  3   Experience  10 non-null     float64
#  4   Gender      10 non-null     object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 480.0+ bytes

# %%
d2.head()
# Out:
#                 Name  Age  Salary  Experience Gender
# 2019-01-01   Himadri   21      15         1.0      F
# 2019-04-01    Hritik   20      36         1.2      M
# 2019-07-01  Sriyanka   22      14         2.0      F
# 2019-10-01   Utkarsh   23      12         0.5      M
# 2020-01-01     Rahul   21      16        11.0      M

# %% [markdown]
# ## **Missing Values**
# - isnull() & notnull()

# %%
df2
# Out:
#        Name   Age  Experience
# 0     Rahul   NaN         1.0
# 1    Shivam  24.0         2.0
# 2     Priti  26.0         NaN
# 3     Uttam   NaN         1.0
# 4    Deepak  26.0         1.2
# 5  Ravindra  22.0         2.0
# 6   Shubham  24.0         2.1
# 7    Anjali  21.0         NaN

# %%
df2.isnull().sum()
# Out:
# Name          0
# Age           2
# Experience    2
# dtype: int64

# %%
df2.isna().sum()
# Out:
# Name          0
# Age           2
# Experience    2
# dtype: int64

# %%
df2.notnull().sum()
# Out:
# Name          8
# Age           6
# Experience    6
# dtype: int64

# %% [markdown]
# ## **Handling the missing values**
# - dropna()
# - fillna()
# - interpolate()

# %%
# dropna()
# df2.dropna(axis = 0, inplace = True)
df2.dropna(axis = 0)
# Out:
#        Name   Age  Experience
# 1    Shivam  24.0         2.0
# 4    Deepak  26.0         1.2
# 5  Ravindra  22.0         2.0
# 6   Shubham  24.0         2.1

# %%
# fillna()
# df2.fillna(0)
# df2.fillna(df2.mean())
# df2.fillna(df2.median())
# df2.fillna({"Age":25, "Experience" : 2})
# df2.fillna(method = 'backfill')
# df2.fillna(method = 'bfill')
# df2.fillna(method = 'ffill')
df2.fillna(method = 'pad')
# Out:
#        Name   Age  Experience
# 0     Rahul   NaN         1.0
# 1    Shivam  24.0         2.0
# 2     Priti  26.0         2.0
# 3     Uttam  26.0         1.0
# 4    Deepak  26.0         1.2
# 5  Ravindra  22.0         2.0
# 6   Shubham  24.0         2.1
# 7    Anjali  21.0         2.1

# %%
df2
# Out:
#        Name   Age  Experience
# 0     Rahul   NaN         1.0
# 1    Shivam  24.0         2.0
# 2     Priti  26.0         NaN
# 3     Uttam   NaN         1.0
# 4    Deepak  26.0         1.2
# 5  Ravindra  22.0         2.0
# 6   Shubham  24.0         2.1
# 7    Anjali  21.0         NaN

# %% [markdown]
# [Interpolation](https://old.amu.ac.in/emp/studym/100003685.pdf)

# %%
df2.interpolate()
# df2.interpolate(method= 'nearest')
# df2.interpolate(method= 'quadratic')
# df2.interpolate(method= 'cubic')
# df2.interpolate(method= 'linear')
# df2.interpolate(method= 'barycentric')
# df2.interpolate(method='polynomial', order=3)
# Out:
#        Name   Age  Experience
# 0     Rahul   NaN         1.0
# 1    Shivam  24.0         2.0
# 2     Priti  26.0         1.5
# 3     Uttam  26.0         1.0
# 4    Deepak  26.0         1.2
# 5  Ravindra  22.0         2.0
# 6   Shubham  24.0         2.1
# 7    Anjali  21.0         2.1

# %% [markdown]
# ### **Statistical Measures**

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df1.mean()
# Out:
# Age           21.80
# Salary        14.80
# Experience     2.08
# dtype: float64

# %%
df1.median()
# Out:
# Age           21.5
# Salary        12.5
# Experience     1.1
# dtype: float64

# %%
df1.var()
# Out:
# Age            2.177778
# Salary        60.177778
# Experience    10.008444
# dtype: float64

# %%
df1.std()
# Out:
# Age           1.475730
# Salary        7.757434
# Experience    3.163613
# dtype: float64

# %%
df1.max()
# Out:
# Name          Utkarsh
# Age                24
# Salary             36
# Experience       11.0
# Gender              M
# dtype: object

# %%
df1.min()
# Out:
# Name          Ayshui
# Age               20
# Salary             9
# Experience       0.5
# Gender             F
# dtype: object

# %%
df1.describe()
# Out:
#             Age     Salary  Experience
# count  10.00000  10.000000   10.000000
# mean   21.80000  14.800000    2.080000
# std     1.47573   7.757434    3.163613
# min    20.00000   9.000000    0.500000
# 25%    21.00000  11.250000    1.000000
# 50%    21.50000  12.500000    1.100000
# 75%    22.75000  14.750000    1.350000
# max    24.00000  36.000000   11.000000

# %% [markdown]
# **Wrong Format data**

# %%
df2['Salary'] = ['$3',"$2.3", "$1.9",'$2.7','$3.3','$2.8','$4.1','$3.5']
df2
# Out:
#        Name   Age  Experience Salary
# 0     Rahul   NaN         1.0     $3
# 1    Shivam  24.0         2.0   $2.3
# 2     Priti  26.0         NaN   $1.9
# 3     Uttam   NaN         1.0   $2.7
# 4    Deepak  26.0         1.2   $3.3
# 5  Ravindra  22.0         2.0   $2.8
# 6   Shubham  24.0         2.1   $4.1
# 7    Anjali  21.0         NaN   $3.5

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Age         6 non-null      float64
#  2   Experience  6 non-null      float64
#  3   Salary      8 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 384.0+ bytes

# %%
df2['Salary'] = pd.to_numeric(df2['Salary'].str.replace('$',''))
df2
# Out:
#        Name   Age  Experience  Salary
# 0     Rahul   NaN         1.0     3.0
# 1    Shivam  24.0         2.0     2.3
# 2     Priti  26.0         NaN     1.9
# 3     Uttam   NaN         1.0     2.7
# 4    Deepak  26.0         1.2     3.3
# 5  Ravindra  22.0         2.0     2.8
# 6   Shubham  24.0         2.1     4.1
# 7    Anjali  21.0         NaN     3.5

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        8 non-null      object
#  1   Age         6 non-null      float64
#  2   Experience  6 non-null      float64
#  3   Salary      8 non-null      float64
# dtypes: float64(3), object(1)
# memory usage: 384.0+ bytes

# %%
# df2['Salary'] = pd.to_numeric(df2['Salary'])
# df2

# %% [markdown]
# **One Hot encoding**

# %%
df1
# Out:
#        Name  Age  Salary  Experience Gender
# 0   Himadri   21      15         1.0      F
# 1    Hritik   20      36         1.2      M
# 2  Sriyanka   22      14         2.0      F
# 3   Utkarsh   23      12         0.5      M
# 4     Rahul   21      16        11.0      M
# 5  Niharika   22      11         1.0      F
# 6  Himanhsu   24      13         1.4      M
# 7    Saloni   21       9         1.2      F
# 8    Ayshui   20      10         0.5      F
# 9    Shivam   24      12         1.0      M

# %%
df1['Gender'].replace({'M': 0,"F":1},inplace = True)

# %%
df1
# Out:
#        Name  Age  Salary  Experience  Gender
# 0   Himadri   21      15         1.0       1
# 1    Hritik   20      36         1.2       0
# 2  Sriyanka   22      14         2.0       1
# 3   Utkarsh   23      12         0.5       0
# 4     Rahul   21      16        11.0       0
# 5  Niharika   22      11         1.0       1
# 6  Himanhsu   24      13         1.4       0
# 7    Saloni   21       9         1.2       1
# 8    Ayshui   20      10         0.5       1
# 9    Shivam   24      12         1.0       0

# %%
df3  = pd.read_csv('/content/df.csv')
df3
# Out:
#        Name  Age  Salary  Experience  Gender
# 0   Himadri   21      15         1.0  Female
# 1    Hritik   20      36         1.2    Male
# 2  Sriyanka   22      14         2.0  Female
# 3   Utkarsh   23      12         0.5    Male
# 4     Rahul   21      16        11.0    Male
# 5  Niharika   22      11         1.0  Female
# 6  Himanhsu   24      13         1.4    Male
# 7    Saloni   21       9         1.2  Female
# 8    Ayshui   20      10         0.5  Female
# 9    Shivam   24      12         1.0    Male

# %%
cat_en, category = df3['Gender'].factorize()

# %%
cat_en
# Out:
# array([0, 1, 0, 1, 1, 0, 1, 0, 0, 1])

# %%
category
# Out:
# Index(['Female', 'Male'], dtype='object')

# %%
df3['Gender'] = cat_en

# %%
df3
# Out:
#        Name  Age  Salary  Experience  Gender
# 0   Himadri   21      15         1.0       0
# 1    Hritik   20      36         1.2       1
# 2  Sriyanka   22      14         2.0       0
# 3   Utkarsh   23      12         0.5       1
# 4     Rahul   21      16        11.0       1
# 5  Niharika   22      11         1.0       0
# 6  Himanhsu   24      13         1.4       1
# 7    Saloni   21       9         1.2       0
# 8    Ayshui   20      10         0.5       0
# 9    Shivam   24      12         1.0       1

# %% [markdown]
# **Merge and joining the dataframe**
# - pd.concat([df1, df2], axis = 0) same as df1.append(df2)
#
# - df1.join(df2)    same as  pd.concat([df1,df2], axis = 1)

# %%
d = df1.iloc[6:,:]

# %%
# df1.append(d)
# pd.concat([d,df1], axis = 0)

# %%
d1 = df1.iloc[:,[0,1,2]]
d2 = df1.iloc[:,[-2,-1]]

# %%
# pd.concat([d1,d2],axis = 1)

# %%
# d2.join(d1)

# %% [markdown]
# ### **gropuby data**

# %%
df = pd.read_csv('/content/df.csv')
df.head()
# Out:
#        Name  Age  Salary  Experience  Gender
# 0   Himadri   21      15         1.0  Female
# 1    Hritik   20      36         1.2    Male
# 2  Sriyanka   22      14         2.0  Female
# 3   Utkarsh   23      12         0.5    Male
# 4     Rahul   21      16        11.0    Male

# %%
group = df.groupby('Gender')

# %%
for i, j in group:
  print(i)
  print()
  print(j)
  print()
# Out:
# Female
#
#        Name  Age  Salary  Experience  Gender
# 0   Himadri   21      15         1.0  Female
# 2  Sriyanka   22      14         2.0  Female
# 5  Niharika   22      11         1.0  Female
# 7    Saloni   21       9         1.2  Female
# 8    Ayshui   20      10         0.5  Female
#
# Male
#
#        Name  Age  Salary  Experience Gender
# 1    Hritik   20      36         1.2   Male
# 3   Utkarsh   23      12         0.5   Male
# 4     Rahul   21      16        11.0   Male
# 6  Himanhsu   24      13         1.4   Male
# 9    Shivam   24      12         1.0   Male

# %%
# first
group.first()
# Out:
#            Name  Age  Salary  Experience
# Gender
# Female  Himadri   21      15         1.0
# Male     Hritik   20      36         1.2

# %%
group.mean()
# Out:
#          Age  Salary  Experience
# Gender
# Female  21.2    11.8        1.14
# Male    22.4    17.8        3.02

# %%
group.median()
# Out:
#          Age  Salary  Experience
# Gender
# Female  21.0    11.0         1.0
# Male    23.0    13.0         1.2

# %%
# group.plot()
group.describe()
# Out:
#          Age                                              Salary        ...  \
#        count  mean      std   min   25%   50%   75%   max  count  mean  ...
# Gender                                                                  ...
# Female   5.0  21.2  0.83666  20.0  21.0  21.0  22.0  22.0    5.0  11.8  ...
# Male     5.0  22.4  1.81659  20.0  21.0  23.0  24.0  24.0    5.0  17.8  ...
#
#                    Experience
#          75%   max      count  mean       std  min  25%  50%  75%   max
# Gender
# Female  14.0  15.0        5.0  1.14  0.545894  0.5  1.0  1.0  1.2   2.0
# Male    16.0  36.0        5.0  3.02  4.473477  0.5  1.0  1.2  1.4  11.0
#
# [2 rows x 24 columns]

# %%
# get_group
fd = group.get_group('Female')

# %%
# get_group
md = group.get_group('Male')
md
# Out:
#        Name  Age  Salary  Experience Gender
# 1    Hritik   20      36         1.2   Male
# 3   Utkarsh   23      12         0.5   Male
# 4     Rahul   21      16        11.0   Male
# 6  Himanhsu   24      13         1.4   Male
# 9    Shivam   24      12         1.0   Male

# %% [markdown]
# ## **I/O Dataframe**

# %%
fd.to_csv('fdata.csv')

# %%
md.to_json('mdata.json')

# %%
fd.to_html('fdat.html')
